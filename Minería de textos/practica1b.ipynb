# %%
#Cargar el corpus LexEsp CorpusLexEsp_UTF8.zip

# !pip install nltk
import nltk
from nltk.corpus import PlaintextCorpusReader
corpus_root = '/workspaces/master-ua/Minería de textos/CorpusLexEsp_UTF8'
wordlists = PlaintextCorpusReader(corpus_root, '.*')
wordlists.fileids()
# Out:
# Requirement already satisfied: nltk in /usr/local/python/3.10.4/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from nltk) (2022.10.31)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# ['a1.txt',
#  'a10.txt',
#  'a11.txt',
#  'a12.txt',
#  'a13.txt',
#  'a14.txt',
#  'a15.txt',
#  'a16.txt',
#  'a17.txt',
#  'a18.txt',
#  'a19.txt',
#  'a2.txt',
#  'a20.txt',
#  'a21.txt',
#  'a22.txt',
#  'a23.txt',
#  'a24.txt',
#  'a25.txt',
#  'a26.txt',
#  'a27.txt',
#  'a28.txt',
#  'a29.txt',
#  'a3.txt',
#  'a30.txt',
#  'a4.txt',
#  'a5.txt',
#  'a6.txt',
#  'a7.txt',
#  'a8.txt',
#  'a9.txt',
#  'c1.txt',
#  'c10.txt',
#  'c2.txt',
#  'c4.txt',
#  'c5.txt',
#  'c6.txt',
#  'c7.1.txt',
#  'c7.2.txt',
#  'c8.txt',
#  'c9.txt',
#  'd1.txt',
#  'd2.txt',
#  'd3.txt',
#  'd4.txt',
#  'd5.1.txt',
#  'd5.2.txt',
#  'd5.3.txt',
#  'dc1.txt',
#  'dc10.txt',
#  'dc2.txt',
#  'dc3.txt',
#  'dc4.1.txt',
#  'dc4.2.txt',
#  'dc4.3.txt',
#  'dc5.txt',
#  'dc6.txt',
#  'dc7.txt',
#  'dc8.txt',
#  'dc9.txt',
#  'e1.txt',
#  'e10.txt',
#  'e11.txt',
#  'e12.txt',
#  'e13.txt',
#  'e14.txt',
#  'e15.txt',
#  'e16.txt',
#  'e17.txt',
#  'e18.1.txt',
#  'e18.2.txt',
#  'e18.3.txt',
#  'e2.txt',
#  'e3.txt',
#  'e4.txt',
#  'e5.txt',
#  'e6.txt',
#  'e7.txt',
#  'e8.txt',
#  'e9.txt',
#  'ed1.txt',
#  'ed2.txt',
#  'ed3.txt',
#  'ed4.1.txt',
#  'ed4.2.txt',
#  'ed4.3.txt',
#  'n1.txt',
#  'n2.1.txt',
#  'n2.2.txt',
#  'n2.3.txt',
#  'n3.txt',
#  'n4.txt',
#  'n5.txt',
#  'n6.txt',
#  'n7.txt',
#  'n8.txt',
#  'r1.txt',
#  'r10.1a.txt',
#  'r10.1b.txt',
#  'r10.1c.txt',
#  'r10.2.txt',
#  'r2.txt',
#  'r3.txt',
#  'r4.txt',
#  'r5.txt',
#  'r6.txt',
#  'r7.txt',
#  'r8.txt',
#  'r9.txt',
#  't1.txt',
#  't10.txt',
#  't11.txt',
#  't12.txt',
#  't13.txt',
#  't14.txt',
#  't15.txt',
#  't16.txt',
#  't17.txt',
#  't18.txt',
#  't19.txt',
#  't2.txt',
#  't20.txt',
#  't21.txt',
#  't22.txt',
#  't23.txt',
#  't24.txt',
#  't25.txt',
#  't26.txt',
#  't27.txt',
#  't28.txt',
#  't29.txt',
#  't3.txt',
#  't30.txt',
#  't31.txt',
#  't32.txt',
#  't33.txt',
#  't34.1.txt',
#  't34.2.txt',
#  't34.3.txt',
#  't34.4.txt',
#  't35.txt',
#  't36.txt',
#  't37.txt',
#  't38.txt',
#  't39.txt',
#  't4.txt',
#  't40.txt',
#  't41.txt',
#  't42.txt',
#  't43.txt',
#  't44.txt',
#  't45.txt',
#  't46.txt',
#  't47.txt',
#  't48.txt',
#  't49.txt',
#  't5.txt',
#  't50.txt',
#  't51.txt',
#  't52.txt',
#  't53.txt',
#  't54.txt',
#  't55.txt',
#  't56.txt',
#  't57.txt',
#  't58.txt',
#  't59.txt',
#  't6.txt',
#  't60.txt',
#  't61.txt',
#  't7.txt',
#  't8.txt',
#  't9.txt']

# %%
# !pip install scikit
# !pip install scikit-learn
# !pip install pyLDAvis
# !pip install gensim
# !pip install spacy
# Out:
# ERROR: Could not find a version that satisfies the requirement scikit (from versions: none)
# ERROR: No matching distribution found for scikit
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn) (1.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn) (1.10.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: pyLDAvis in /usr/local/python/3.10.4/lib/python3.10/site-packages (3.3.1)
# Requirement already satisfied: future in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyLDAvis) (0.18.3)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.10/site-packages (from pyLDAvis) (1.2.1)
# Requirement already satisfied: gensim in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyLDAvis) (4.3.0)
# Requirement already satisfied: pandas>=1.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from pyLDAvis) (1.5.3)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: numexpr in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyLDAvis) (2.8.4)
# Requirement already satisfied: funcy in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyLDAvis) (1.18)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyLDAvis) (58.1.0)
# Requirement already satisfied: numpy>=1.20.0 in /home/codespace/.local/lib/python3.10/site-packages (from pyLDAvis) (1.24.1)
# Requirement already satisfied: sklearn in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyLDAvis) (0.0.post1)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from pyLDAvis) (1.10.0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.2.0->pyLDAvis) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from gensim->pyLDAvis) (2.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->pyLDAvis) (2.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn->pyLDAvis) (3.1.0)
# Requirement already satisfied: pyfume in /usr/local/python/3.10.4/lib/python3.10/site-packages (from FuzzyTM>=0.4.0->gensim->pyLDAvis) (0.2.25)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: simpful in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2.9.0)
# Requirement already satisfied: fst-pso in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (1.8.1)
# Requirement already satisfied: miniful in /usr/local/python/3.10.4/lib/python3.10/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (0.0.6)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2.28.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (3.4)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: gensim in /usr/local/python/3.10.4/lib/python3.10/site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/codespace/.local/lib/python3.10/site-packages (from gensim) (1.24.1)
# Requirement already satisfied: scipy>=1.7.0 in /home/codespace/.local/lib/python3.10/site-packages (from gensim) (1.10.0)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from gensim) (2.0.5)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from gensim) (6.3.0)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.10/site-packages (from FuzzyTM>=0.4.0->gensim) (1.5.3)
# Requirement already satisfied: pyfume in /usr/local/python/3.10.4/lib/python3.10/site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: fst-pso in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: simpful in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.9.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in /usr/local/python/3.10.4/lib/python3.10/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.26.14)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import spacy
import pandas as pd
import numpy as np
import os
import nltk
# !python3 -m spacy download en_core_web_sm
# !python3 -m spacy download es_core_web_sm
# !pip install es-core-news-sm
from spacy.lang.es.examples import sentences 


# Vamos a leer todos los corpus de la ruta /Users/ahmedbegga/Desktop/Master Ciencia de Datos/Mineria de textos/Materiales_PracticaTopicModeling/CorpusLexEsp_UTF8
# y almacenarlos en una lista ya tokenizados y unicamente con los nombres, verbos y adjetivos
# Vamos a leer las stopwords en español de la siguiente ruta /Users/ahmedbegga/Desktop/Master Ciencia de Datos/Mineria de textos/Materiales_PracticaTopicModeling/stopwords/stopwords.txt
stopwords = []
with open("/workspaces/master-ua/Minería de textos/stopwords/stopwords.txt",encoding="utf8") as f:
    stopwords = f.read().splitlines()
corpus = []
for filename in os.listdir("/workspaces/master-ua/Minería de textos/CorpusLexEsp_UTF8/"):
    if filename.endswith(".txt"):
        with open("/workspaces/master-ua/Minería de textos/CorpusLexEsp_UTF8/"+filename,encoding="utf8") as f:
            text = f.read()
            # Vamos a tokenizar el texto con spacy
            nlp = spacy.load("es_core_news_sm")
            doc = nlp(text)
            # Vamos a almacenar en una lista los tokens que sean nombres, verbos o adjetivos
            tokens = []
            for token in doc:
                if token.pos_ in ["NOUN","VERB","ADJ"]:
                    tokens.append(token.text)
            # Vamos a eliminar las stopwords de cada documento del corpus
            tokens = [word for word in tokens if word not in stopwords]
            corpus.append(tokens)
corpus

# Vamos a crear el diccionario
dictionary = corpora.Dictionary(corpus)
# Vamos a crear el corpus
doc_term_matrix = [dictionary.doc2bow(doc) for doc in corpus]

# Vamos a crear el modelo LDA
Lda = gensim.models.ldamodel.LdaModel
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)
print(ldamodel.print_topics(num_topics=3, num_words=3))

#Visualiza el modelo LDA
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary)
vis
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 76.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from en-core-web-sm==3.1.0) (3.1.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.9)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.28.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.9)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (58.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.12)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (23.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.17)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (6.3.0)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.1.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.64.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.24.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2022.12.7)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.1.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
#
# ✘ No compatible package found for 'es_core_web_sm' (spaCy v3.1.7)
#
# Requirement already satisfied: es-core-news-sm in /usr/local/python/3.10.4/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from es-core-news-sm) (3.1.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.28.2)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.8.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.4.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (6.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.24.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (58.1.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (8.0.17)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.1.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.7.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->es-core-news-sm) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (2022.12.7)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.1.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# [(0, '0.003*"dijo" + 0.003*"casa" + 0.003*"vida"'), (1, '0.004*"años" + 0.003*"forma" + 0.003*"parte"'), (2, '0.004*"años" + 0.003*"tiene" + 0.003*"parte"')]
# /usr/local/python/3.10.4/lib/python3.10/site-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.120172  0.027899       1        1  48.160969
# 2      0.021630 -0.079335       2        1  38.417108
# 1      0.098542  0.051437       3        1  13.421922, topic_info=          Term         Freq        Total Category  logprob  loglift
# 160       años  6136.000000  6136.000000  Default  30.0000  30.0000
# 683      forma  2654.000000  2654.000000  Default  29.0000  29.0000
# 1078     parte  3710.000000  3710.000000  Default  28.0000  28.0000
# 4442   sistema  1272.000000  1272.000000  Default  27.0000  27.0000
# 3567  millones  1610.000000  1610.000000  Default  26.0000  26.0000
# ...        ...          ...          ...      ...      ...      ...
# 1012     mundo   352.161986  3589.705726   Topic3  -6.6204  -0.3135
# 3080     hecho   319.478550  2880.746396   Topic3  -6.7178  -0.1908
# 414      decir   319.855617  3019.080741   Topic3  -6.7166  -0.2366
# 1153   posible   296.194026  1586.449268   Topic3  -6.7935   0.3300
# 996    momento   303.202639  2838.486317   Topic3  -6.7701  -0.2283
#
# [326 rows x 6 columns], token_table=       Topic      Freq    Term
# term
# 21035      1  0.991168    Fría
# 11580      1  0.989270   Pensó
# 5146       1  0.987202   Sabía
# 14598      1  0.956166  abuela
# 14598      2  0.042496  abuela
# ...      ...       ...     ...
# 36478      1  0.019650  átomos
# 36478      2  0.117901  átomos
# 36478      3  0.854785  átomos
# 36486      1  0.028485   óvulo
# 36486      3  0.968478   óvulo
#
# [620 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 3, 2])
