# %%
#Cargar el corpus LexEsp CorpusLexEsp_UTF8.zip

# !pip install nltk
import nltk
from nltk.corpus import PlaintextCorpusReader
corpus_root = '/workspaces/master-ua/Minería de textos/CorpusLexEsp_UTF8'
wordlists = PlaintextCorpusReader(corpus_root, '.*')
wordlists.fileids()
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# ['a1.txt',
#  'a10.txt',
#  'a11.txt',
#  'a12.txt',
#  'a13.txt',
#  'a14.txt',
#  'a15.txt',
#  'a16.txt',
#  'a17.txt',
#  'a18.txt',
#  'a19.txt',
#  'a2.txt',
#  'a20.txt',
#  'a21.txt',
#  'a22.txt',
#  'a23.txt',
#  'a24.txt',
#  'a25.txt',
#  'a26.txt',
#  'a27.txt',
#  'a28.txt',
#  'a29.txt',
#  'a3.txt',
#  'a30.txt',
#  'a4.txt',
#  'a5.txt',
#  'a6.txt',
#  'a7.txt',
#  'a8.txt',
#  'a9.txt',
#  'c1.txt',
#  'c10.txt',
#  'c2.txt',
#  'c4.txt',
#  'c5.txt',
#  'c6.txt',
#  'c7.1.txt',
#  'c7.2.txt',
#  'c8.txt',
#  'c9.txt',
#  'd1.txt',
#  'd2.txt',
#  'd3.txt',
#  'd4.txt',
#  'd5.1.txt',
#  'd5.2.txt',
#  'd5.3.txt',
#  'dc1.txt',
#  'dc10.txt',
#  'dc2.txt',
#  'dc3.txt',
#  'dc4.1.txt',
#  'dc4.2.txt',
#  'dc4.3.txt',
#  'dc5.txt',
#  'dc6.txt',
#  'dc7.txt',
#  'dc8.txt',
#  'dc9.txt',
#  'e1.txt',
#  'e10.txt',
#  'e11.txt',
#  'e12.txt',
# ...

# %%
# !pip install scikit
# !pip install scikit-learn
# !pip install pyLDAvis
# !pip install gensim
#tokeniza el corpus cargado anteriormente y filtra "stopwords"
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('spanish'))
word_tokens = word_tokenize(wordlists.raw())
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
# print(word_tokens)
# print(filtered_sentence)

#calcula la frecuencia de las palabras
from nltk.probability import FreqDist
fdist = FreqDist(filtered_sentence)
# print(fdist)


#selecciona las categorías de interés
from nltk.corpus import CategorizedPlaintextCorpusReader
corpus = CategorizedPlaintextCorpusReader(corpus_root, r'.*\.txt', cat_pattern=r'(\w+)/*') #aqui tenemos las categorias

#Crea el modelo LDA con Gensim


import gensim
from gensim import corpora
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import spacy
import string
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

#crea el diccionario
dictionary = corpora.Dictionary([filtered_sentence])
#crea el corpus
doc_term_matrix = [dictionary.doc2bow(doc) for doc in [filtered_sentence]]
#crea el modelo LDA
Lda = gensim.models.ldamodel.LdaModel
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)
print(ldamodel.print_topics(num_topics=3, num_words=3))

#Visualiza el modelo LDA
pyLDAvis.enable_notebook()
#vis = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary)
vis
# Out:
# ERROR: Could not find a version that satisfies the requirement scikit (from versions: none)
# ERROR: No matching distribution found for scikit
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 33
#      31 import gensim
#      32 from gensim import corpora
# ---> 33 import pyLDAvis.gensim
#      34 import matplotlib.pyplot as plt
#      35 import numpy as np
#
# ...

# %%
# !pip install pyLDAvis
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python -m pip install --upgrade pip
