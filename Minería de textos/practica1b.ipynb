# %%
# !pip install scikit
# !pip install scikit-learn
# !pip install pyLDAvis
# !pip install gensim
# !pip install spacy
# !pip install nltk
# !python3 -m spacy download en_core_web_sm
# !python3 -m spacy download es_core_web_sm
# !pip install es-core-news-sm



import gensim
import nltk
import pyLDAvis
from spacy.lang.es.examples import sentences 
from nltk.corpus import PlaintextCorpusReader

corpus_root = '/Users/usuario/entorno/master-ua/Minería de textos/CorpusLexEsp_UTF8'
wordlists = PlaintextCorpusReader(corpus_root, '.*')
wordlists.fileids()


import spacy
import pandas as pd
import numpy as np
import os
import nltk
# Vamos a leer todos los corpus de la ruta /Users/ahmedbegga/Desktop/Master Ciencia de Datos/Mineria de textos/Materiales_PracticaTopicModeling/CorpusLexEsp_UTF8
# y almacenarlos en una lista ya tokenizados y unicamente con los nombres, verbos y adjetivos
# Vamos a leer las stopwords en español de la siguiente ruta /Users/ahmedbegga/Desktop/Master Ciencia de Datos/Mineria de textos/Materiales_PracticaTopicModeling/stopwords/stopwords.txt
stopwords = []
with open("/Users/usuario/entorno/master-ua/Minería de textos/stopwords/stopwords.txt",encoding="utf8") as f:
    stopwords = f.read().splitlines()
corpus = []
for filename in os.listdir("/Users/usuario/entorno/master-ua/Minería de textos/CorpusLexEsp_UTF8"):
    if filename.endswith(".txt"):
        with open("/Users/usuario/entorno/master-ua/Minería de textos/CorpusLexEsp_UTF8/"+filename,encoding="utf8") as f:
            text = f.read()
            # Vamos a tokenizar el texto con spacy
            nlp = spacy.load("es_core_news_sm")
            doc = nlp(text)
            # Vamos a almacenar en una lista los tokens que sean nombres, verbos o adjetivos
            tokens = []
            for token in doc:
                if token.pos_ in ["NOUN","VERB","ADJ"]:
                    tokens.append(token.text)
            # Vamos a eliminar las stopwords de cada documento del corpus
            tokens = [word for word in tokens if word not in stopwords]
            corpus.append(tokens)
corpus

# Vamos a crear un diccionario con los tokens de todos los documentos del corpus
dictionary = gensim.corpora.Dictionary(corpus)
# Vamos a crear un corpus con los tokens de todos los documentos del corpus
doc_term_matrix = [dictionary.doc2bow(doc) for doc in corpus]

# Vamos a crear el modelo LDA
Lda = gensim.models.ldamodel.LdaModel
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)
print(ldamodel.print_topics(num_topics=3, num_words=3))

#Visualiza el modelo LDA
pyLDAvis.enable_notebook()
from pyLDAvis import gensim_models
vis = gensim_models.prepare(ldamodel, doc_term_matrix, dictionary)
vis
# Out:
# ERROR: Could not find a version that satisfies the requirement scikit
# ERROR: No matching distribution found for scikit
# Requirement already satisfied: scikit-learn in c:\users\usuario\miniconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\usuario\miniconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\usuario\miniconda3\lib\site-packages (from scikit-learn) (1.22.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\usuario\miniconda3\lib\site-packages (from scikit-learn) (1.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\miniconda3\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\usuario\miniconda3\lib\site-packages (from scikit-learn) (1.22.1)
# Requirement already satisfied: pyLDAvis in c:\users\usuario\miniconda3\lib\site-packages (3.4.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: jinja2 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: scipy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.8.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: pandas>=1.3.4 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.4.0)
# Requirement already satisfied: setuptools in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (58.0.0)
# Requirement already satisfied: funcy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.18)
# Requirement already satisfied: gensim in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (4.3.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: numexpr in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (2.8.4)
# Requirement already satisfied: Cython==0.29.32 in c:\users\usuario\miniconda3\lib\site-packages (from gensim->pyLDAvis) (0.29.32)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\usuario\miniconda3\lib\site-packages (from gensim->pyLDAvis) (2.0.5)
# Requirement already satisfied: scipy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.8.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: pandas>=1.3.4 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.4.0)
# Requirement already satisfied: scipy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.8.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: pyfume in c:\users\usuario\miniconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim->pyLDAvis) (0.2.25)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\usuario\miniconda3\lib\site-packages (from jinja2->pyLDAvis) (1.1.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\miniconda3\lib\site-packages (from pandas>=1.3.4->pyLDAvis) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from pandas>=1.3.4->pyLDAvis) (2.8.1)
# Requirement already satisfied: simpful in c:\users\usuario\miniconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2.10.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: fst-pso in c:\users\usuario\miniconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (1.8.1)
# Requirement already satisfied: scipy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.8.0)
# Requirement already satisfied: miniful in c:\users\usuario\miniconda3\lib\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (0.0.6)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: scipy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->pyLDAvis) (1.15.0)
# Requirement already satisfied: scipy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.8.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\miniconda3\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.1.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: requests in c:\users\usuario\miniconda3\lib\site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2.27.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.22.1)
# Requirement already satisfied: scipy in c:\users\usuario\miniconda3\lib\site-packages (from pyLDAvis) (1.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (1.25.11)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2020.12.5)
# Requirement already satisfied: gensim in c:\users\usuario\miniconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (6.3.0)
# Requirement already satisfied: Cython==0.29.32 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (0.29.32)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.8.0)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in c:\users\usuario\miniconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (1.4.0)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.8.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: pyfume in c:\users\usuario\miniconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\miniconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: simpful in c:\users\usuario\miniconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.10.0)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.8.0)
# Requirement already satisfied: fst-pso in c:\users\usuario\miniconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: miniful in c:\users\usuario\miniconda3\lib\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.8.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: requests in c:\users\usuario\miniconda3\lib\site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.27.1)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.8.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usuario\miniconda3\lib\site-packages (from gensim) (1.22.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario\miniconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.25.11)
# Requirement already satisfied: spacy in c:\users\usuario\miniconda3\lib\site-packages (3.1.7)
# Requirement already satisfied: jinja2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (0.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: setuptools in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (58.0.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (8.0.17)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (4.54.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.22.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (6.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (0.7.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.22.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\usuario\miniconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (0.4.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (6.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\usuario\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: setuptools in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (58.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (1.22.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\usuario\miniconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: colorama in c:\users\usuario\miniconda3\lib\site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy) (0.4.6)
# Requirement already satisfied: nltk in c:\users\usuario\miniconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: tqdm in c:\users\usuario\miniconda3\lib\site-packages (from nltk) (4.54.1)
# Requirement already satisfied: joblib in c:\users\usuario\miniconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\usuario\miniconda3\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in c:\users\usuario\miniconda3\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: colorama in c:\users\usuario\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# C:\Users\usuario\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe: No module named spacy
# C:\Users\usuario\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe: No module named spacy
# Requirement already satisfied: es-core-news-sm in c:\users\usuario\miniconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in c:\users\usuario\miniconda3\lib\site-packages (from es-core-news-sm) (3.1.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (4.54.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.10.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.4.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.22.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.7.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.27.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (8.0.17)
# Requirement already satisfied: setuptools in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (58.0.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.22.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\usuario\miniconda3\lib\site-packages (from jinja2->spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.4.7)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.4.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\usuario\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->es-core-news-sm) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.8)
# Requirement already satisfied: setuptools in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (58.0.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.22.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.7.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (2.4.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\usuario\miniconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.10.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\usuario\miniconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (8.1.3)
# Requirement already satisfied: colorama in c:\users\usuario\miniconda3\lib\site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->es-core-news-sm) (0.4.6)
