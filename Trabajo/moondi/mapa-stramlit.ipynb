# %%
#instalamos y importamos streamlit
# !pip install streamlit
import streamlit as st

#ahora vamos a leer el csv con los datos
import pandas as pd
df = pd.read_csv(r'\Users\usuario\entorno\master-ua\Trabajo y relacionados\moondi\Tripadvisor_Los_Angeles - Hoja 1 (1).csv', na_values=None)

#mostramos el head del dataframe
df.head()
# Out:
# ...
#   Using cached streamlit-1.19.0-py2.py3-none-any.whl (9.6 MB)
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# ...
#   Using cached pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
# ...
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# ...
#   Using cached blinker-1.5-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached watchdog-2.3.1-py3-none-win_amd64.whl (80 kB)
# ...
#   Using cached semver-2.13.0-py2.py3-none-any.whl (12 kB)
# ...
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ----------- ---------------------------- 0.7/2.5 MB 23.1 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 31.6 MB/s eta 0:00:00
# ...
#   Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# ...
#      ---------------------------------------- 0.0/20.6 MB ? eta -:--:--
#      ------- -------------------------------- 3.6/20.6 MB 77.3 MB/s eta 0:00:01
# ...

# %%
#mostramos un hola mundo en streamlit

st.write('Hola mundo')
# Out:
# 2023-03-07 10:48:11.705
# ...
#   command:
#
#     streamlit run C:\Users\usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
