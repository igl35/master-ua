# %%
#dada una imagen que contiene rectágulos, extrae la mascara de cada uno de ellos y calcula los bbox de cada uno de ellos
#la imagen debe estar en escala de grises
#instala cv2
# !pip install libGL
# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib

#importa open cv

import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import pandas as pd
import math
import random
import time
import sys
import shutilS
import csv
import re
import math

#funcion para extraer la mascara de cada rectangulo que hay en la imagen
def get_mask(img):
    # Find contours
    contours, hierarchy = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    # Create empty mask
    mask = np.zeros(img.shape, dtype=np.uint8)
    # Fill mask
    cv2.drawContours(mask, contours, -1, 255, -1)
    return mask 

#ahora dada las máscara calculamos el bbox
def get_bbox(mask):
    # Find bounding box
    points = np.argwhere(mask>0)
    points = np.fliplr(points)
    x, y, w, h = cv2.boundingRect(points)
    return x,y,w,h

#funcion para dibujar el bbox
def draw_bbox(img,rect):
    x,y,w,h = rect
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    return img

#pon un ejemplo de como se usa
if __name__ == '__main__':
    # Load image
    img = cv2.imread('/workspaces/master-ua/Trabajo y relacionados/360_F_224074427_xJpLTE2OAvSG3LNKt5WGpKoQPaOTEeu1.jpg',0)
    # Get mask
    mask = get_mask(img)
    # Get bounding box
    rect = get_bbox(mask)
    # Draw bounding box
    img = draw_bbox(img,rect)
    # Show image
    cv2.imshow('img',img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# ERROR: Could not find a version that satisfies the requirement libGL (from versions: none)
# ERROR: No matching distribution found for libGL
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in /usr/local/python/3.10.4/lib/python3.10/site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.19.3 in /home/codespace/.local/lib/python3.10/site-packages (from opencv-python) (1.24.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (1.24.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: numpy>=1.19 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 11
#       7 get_ipython().system('pip install matplotlib')
#       9 #importa open cv
# ---> 11 import cv2
#      12 import numpy as np
#      13 import matplotlib.pyplot as plt
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory
